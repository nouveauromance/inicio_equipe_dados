# %% [markdown]
# LINKs:
# [como documentar o seu notebook](https://franciscofoz.medium.com/como-documentar-o-seu-notebook-em-projetos-de-ci%C3%AAncia-de-dados-9b238cc7c565)

# %% [markdown]
# # Título do Projeto: [Nome claro e descritivo do projeto]
# **Autor(a):** [O seu Nome]
#
# **Data:** [Data de início/atualização]
#
# **Objetivo:** [Breve parágrafo a descrever o problema de negócio ou a pergunta de pesquisa que este projeto visa responder, como por exemplo, identificar fatores de risco para uma determinada condição.]

# %% [markdown]
# ---
# ## 1. Importação de Bibliotecas
# *Nesta secção, concentre todas as dependências necessárias para o projeto. Organizar por categorias facilita a leitura:*
# - Manipulação de dados
# - Visualização
# - Modelagem e Machine Learning
# - Métricas e Avaliação

# %% [markdown]
# ---
# ## 2. Carregamento dos Dados
# *Espaço reservado para a leitura das bases de dados originais.*
# - **Fonte dos dados:** [Ex: Repositório público, base de dados interna, extração via API]
# - **Dicionário de dados:** [Link ou breve descrição do que cada variável representa]
# - Verificação inicial das dimensões do conjunto de dados (linhas e colunas).

# %% [markdown]
# ---
# ## 3. Análise Exploratória de Dados (EDA)
# *O objetivo aqui é conhecer o comportamento das variáveis antes de qualquer transformação.*
# - **Visualização inicial:** Visualização das primeiras e últimas linhas.
# - **Estatística Descritiva:** Resumo estatístico das variáveis numéricas (média, mediana, desvio padrão) e contagem das categóricas.
# - **Análise Univariada:** Distribuição individual de cada variável (histogramas, boxplots).
# - **Análise Bivariada e Multivariada:** Relação entre as variáveis independentes e a variável alvo. Matriz de correlação para identificar multicolinearidade.

# %% [markdown]
# ---
# ## 4. Pré-processamento e Limpeza de Dados
# *Etapa de tratamento de inconsistências para garantir a qualidade da informação que alimentará o modelo.*
# - **Tratamento de Valores Ausentes (NaNs):** Estratégias de imputação ou remoção justificadas.
# - **Tratamento de Outliers:** Identificação e gestão de valores atípicos.
# - **Correção de Tipos de Dados:** Ajuste de variáveis que foram lidas incorretamente.
# - **Remoção de Duplicatas:** Verificação e exclusão de registos repetidos.

# %% [markdown]
# ---
# ## 5. Engenharia de Atributos (Feature Engineering)
# *Criação ou transformação de variáveis para melhorar o poder preditivo do modelo.*
# - **Criação de novas variáveis:** Derivar informações mais úteis a partir das existentes.
# - **Codificação de Variáveis Categóricas:** Transformação de texto em números (One-Hot Encoding, Label Encoding).
# - **Escalonamento de Variáveis (Scaling/Normalization):** Padronização de escalas.

# %% [markdown]
# ---
# ## 6. Divisão dos Dados
# *Separação do conjunto de dados para garantir que o modelo seja avaliado em dados não vistos.*
# - **Definição de X (variáveis preditoras) e y (variável alvo).**
# - **Separação em Treino e Teste:** (e opcionalmente, Validação).
# - **Estratificação:** Garantir que a proporção das classes se mantenha.

# %% [markdown]
# ---
# ## 7. Modelagem (Machine Learning)
# *A fase de treino propriamente dita.*
# - **Definição do(s) Modelo(s) Base (Baseline):** Um modelo simples para servir de ponto de comparação inicial.
# - **Treino de Modelos Avançados:** Experimentação com algoritmos mais complexos.
# - **Ajuste de Hiperparâmetros (Tuning):** Otimização dos parâmetros internos dos modelos selecionados.

# %% [markdown]
# ---
# ## 8. Avaliação e Validação do Modelo
# *Medição da performance do modelo nos dados de teste.*
# - **Métricas de Desempenho:** Escolha das métricas adequadas ao problema.
# - **Matriz de Confusão:** Visualização dos acertos e erros.
# - **Validação Cruzada (Cross-Validation):** Garantia de que o modelo generaliza bem e não sofre de overfitting.

# %% [markdown]
# ---
# ## 9. Interpretabilidade do Modelo
# *Explicar como o modelo toma decisões.*
# - **Importância das Variáveis (Feature Importance):** Identificar quais atributos têm maior peso na predição.
# - **Análise de Erros:** Avaliar os casos em que o modelo falhou e tentar perceber o padrão desses erros.

# %% [markdown]
# ---
# ## 10. Conclusão e Próximos Passos
# *Fecho do estudo com os resultados e direções futuras.*
# - **Resumo dos Resultados:** O modelo resolveu o problema inicial? Qual foi o desempenho final?
# - **Limitações do Estudo:** Reconhecimento de enviesamentos nos dados ou restrições metodológicas.
# - **Trabalhos Futuros:** O que pode ser testado numa próxima iteração.
